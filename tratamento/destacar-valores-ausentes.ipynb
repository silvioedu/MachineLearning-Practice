# %% [markdown]
# # Destacando valores ausentes

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'Nome': ['Lucas', 'Pedro', np.nan, 'Paulo', 'Eliana', 'Mateus', 'Jander', 'Lucas', 'Dayana', 'Ricardo'],
    'Idade': [16, np.nan, 23, 17, 32, 65, 36, np.nan, 33, 18]
})

# %%
df
# Out:
#       Nome  Idade
# 0    Lucas   16.0
# 1    Pedro    NaN
# 2      NaN   23.0
# 3    Paulo   17.0
# 4   Eliana   32.0
# 5   Mateus   65.0
# 6   Jander   36.0
# 7    Lucas    NaN
# 8   Dayana   33.0
# 9  Ricardo   18.0

# %%
df.style.highlight_null(null_color='red')
# Out:
# <style  type="text/css" >
# #T_86b4098c_e265_11ea_9114_0242ac130202row1_col1,#T_86b4098c_e265_11ea_9114_0242ac130202row2_col0,#T_86b4098c_e265_11ea_9114_0242ac130202row7_col1{
#             background-color:  red;
#         }</style><table id="T_86b4098c_e265_11ea_9114_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Nome</th>        <th class="col_heading level0 col1" >Idade</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86b4098c_e265_11ea_9114_0242ac130202level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_86b4098c_e265_11ea_9114_0242ac130202row0_col0" class="data row0 col0" >Lucas</td>
#                         <td id="T_86b4098c_e265_11ea_9114_0242ac130202row0_col1" class="data row0 col1" >16.000000</td>
#             </tr>
#             <tr>
# ...
